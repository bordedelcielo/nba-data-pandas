# %% [markdown]
# # Nba Regular Season 2018-19 Data Challenge
#
# Your task will be to take the dataset given, and create an analysis answering the following 10 questions. This project will again test your knowledge of pandas in order to find the answers needed given the data you are presented with.

# %% [markdown]
# # What was the average age of player in the league?

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # What player scored the most points?

# %%
nba_data = pd.read_csv('nbastats2018-2019.csv')
nba_data.sort_values('Points', ascending = False)[['Name', 'Points']]

# James Harden
# Out:
#                       Name  Points
# 202           James Harden    36.1
# 179            Paul George    28.0
# 15   Giannis Antetokounmpo    27.7
# 151            Joel Embiid    27.5
# 253           LeBron James    27.4
# ..                     ...     ...
# 192         Donte Grantham     0.0
# 242           Andre Ingram     0.0
# 498            Okaro White     0.0
# 442           Kobi Simmons     0.0
# 14            Ike Anigbogu     0.0
#
# [521 rows x 2 columns]

# %% [markdown]
# # What player had the most blocks during the season? Was it a post player (F/C)?

# %%
nba_data.sort_values('Blocks', ascending = False)[['Name', 'Blocks']]

# Myles Turner
# Out:
#                    Name  Blocks
# 476        Myles Turner     2.7
# 123       Anthony Davis     2.4
# 419   Mitchell Robinson     2.4
# 183         Rudy Gobert     2.3
# 303         Brook Lopez     2.2
# ..                  ...     ...
# 416     Duncan Robinson     0.0
# 413  Malachi Richardson     0.0
# 410          Davon Reed     0.0
# 259        B.J. Johnson     0.0
# 147        Trevon Duval     0.0
#
# [521 rows x 2 columns]

# %% [markdown]
# # Based on the regular season, who had the best chance to win a title given their win percentage?

# %%
nba_data.columns
# Out:
# Index(['Name', 'Height', 'Weight', 'Team', 'Age', 'Salary', 'Points', 'Blocks',
#        'Steals', 'Assists', 'Rebounds', 'FT%', 'FTA', 'FG3%', 'FG3A', 'FG%',
#        'FGA', 'MP', 'G', 'PER', 'OWS', 'DWS', 'WS', 'WS48', 'USG', 'BPM',
#        'VORP'],
#       dtype='object')

# %%
nba_data.nlargest(5, 'WS')[['Name', 'WS']]

# James Harden
# Out:
#                       Name    WS
# 202           James Harden  15.2
# 15   Giannis Antetokounmpo  14.4
# 183            Rudy Gobert  14.4
# 299         Damian Lillard  12.1
# 179            Paul George  11.9

# %% [markdown]
# # What player had the best 3-pt percentage?

# %%
nba_data.nlargest(5, 'FG3%')[['Name', 'FG3%']]

# Scott Machado, Jordan Sibert, Trevor Duval, and Eric Moreland are tied at 1.0.
# Out:
#               Name   FG3%
# 147   Trevon Duval  1.000
# 312  Scott Machado  1.000
# 352  Eric Moreland  1.000
# 439  Jordan Sibert  1.000
# 95    Troy Caupain  0.667

# %% [markdown]
# # Who played the most minutes during the season

# %%
# Use win share divided by win share per 48 minutes times 48 to get the minutes.

nba_data['Minutes Played'] = nba_data['WS'] * 1/(nba_data['WS48']) * 48

nba_data.nlargest(5, 'Minutes Played')

# Bradley Beal
# Out:
#               Name  Height  Weight                   Team  Age    Salary  \
# 37    Bradley Beal      77     207     Washington Wizards   25  25434263
# 486   Kemba Walker      73     184      Charlotte Hornets   28  12000000
# 202   James Harden      77     220        Houston Rockets   29  30431854
# 179    Paul George      81     220  Oklahoma City Thunder   28  30560700
# 208  Tobias Harris      81     235     Philadelphia 76ers   26  14800000
#
#      Points  Blocks  Steals  Assists  ...   G   PER   OWS  DWS    WS   WS48  \
# 37     25.6     0.7     1.5      5.5  ...  82  20.8   5.9  1.7   7.6  0.120
# 486    25.6     0.4     1.2      5.9  ...  82  21.7   5.5  1.9   7.4  0.123
# 202    36.1     0.7     2.0      7.5  ...  78  30.6  11.4  3.8  15.2  0.254
# 179    28.0     0.4     2.2      4.1  ...  77  23.3   7.0  4.9  11.9  0.201
# 208    20.0     0.5     0.6      2.8  ...  82  17.2   4.5  2.6   7.1  0.120
#
#       USG   BPM  VORP  Minutes Played
# ...

# %% [markdown]
# # What player given their player effiecency rating was the clutchest during the season?

# %%
nba_data.columns
# Out:
# Index(['Name', 'Height', 'Weight', 'Team', 'Age', 'Salary', 'Points', 'Blocks',
#        'Steals', 'Assists', 'Rebounds', 'FT%', 'FTA', 'FG3%', 'FG3A', 'FG%',
#        'FGA', 'MP', 'G', 'PER', 'OWS', 'DWS', 'WS', 'WS48', 'USG', 'BPM',
#        'VORP', 'Minutes Played'],
#       dtype='object')

# %%
# calculate dividend of efficiency and points.

nba_data['Points / PER'] = nba_data['Points'] / nba_data['PER']

nba_data.nlargest(5, 'Points / PER')

# Jawun Evans
# Out:
#                    Name  Height  Weight                  Team  Age   Salary  \
# 155         Jawun Evans      72     185  Los Angeles Clippers   22  1378242
# 461       Jared Terrell      75     227                   NaN   23        -
# 413  Malachi Richardson      78     205    Philadelphia 76ers   23  1569360
# 279          Kevin Knox      81     215       New York Knicks   19  3739920
# 26         Wade Baldwin      76     200        Indiana Pacers   22  1544951
#
#      Points  Blocks  Steals  Assists  ...  PER  OWS  DWS   WS   WS48   USG  \
# 155     0.8     0.0     0.4      1.3  ...  0.1 -0.2  0.0 -0.2 -0.151  13.2
# 461     2.2     0.1     0.2      0.9  ...  0.7 -0.4  0.0 -0.3 -0.140  19.6
# 413     1.4     0.0     0.0      0.0  ...  0.9 -0.2  0.1 -0.1 -0.060  16.4
# 279    12.8     0.3     0.6      1.1  ...  8.7 -2.2  0.9 -1.3 -0.030  22.3
# 26      1.9     0.1     0.1      0.8  ...  1.3 -0.4  0.1 -0.3 -0.153  23.3
#
#       BPM  VORP  Minutes Played  Points / PER
# ...

# %% [markdown]
# # What team had the youngest roster?

# %%
# group by team

nba_data.groupby(['Team']).count()
# Out:
#                         Name  Height  Weight  Age  Salary  Points  Blocks  \
# Team
# Atlanta Hawks             21      21      21   21      21      21      21
# Boston Celtics            15      15      15   15      15      15      15
# Brooklyn Nets             18      18      18   18      18      18      18
# Charlotte Hornets         14      14      14   14      14      14      14
# Chicago Bulls             16      16      16   16      16      16      16
# Cleveland Cavaliers       16      16      16   16      16      16      16
# Dallas Mavericks          15      15      15   15      15      15      15
# Denver Nuggets            15      15      15   15      15      15      15
# Detroit Pistons           15      15      15   15      15      15      15
# Golden State Warriors     15      15      15   15      15      15      15
# Houston Rockets           13      13      13   13      13      13      13
# Indiana Pacers            17      17      17   17      17      17      17
# ...

# %% [markdown]
# # Who is the highest paid player during the seasion?

# %%
salary_list = []
player_list = []
d = {}

for i in range(521):
    if nba_data['Salary'][i].isdigit():
        salary_list.append(int(nba_data['Salary'][i]))
        player_list.append(nba_data['Name'][i])
        d[int(nba_data['Salary'][i])] = nba_data['Name'][i]
#         print(int(nba_data['Salary'][i]), nba_data['Name'][i])
    
print(max(salary_list))
for i in salary_list:
    count = 0
    if i >= 37457154:
        print('Oh no', count)
        count += 1
print(d[max(salary_list)])

# Stephen Curry
# Out:
# 37457154
# Oh no 0
# Stephen Curry

# %% [markdown]
# # At the end of a game, who WOULDN'T you want on the Free Throw Line?

# %%
# nba_data.columns

nba_data.nsmallest(20, 'FT%')[['Name', 'FT%']]

# Jacob Evens, Haywood Highsmith, Terrence Jones, Tahjere McCall, Donatas Motiejunas, Dzanan Musa, and C.J. Williams
# each have FT%'s of 0.000.
# Out:
#                      Name    FT%
# 154           Jacob Evans  0.000
# 221     Haywood Highsmith  0.000
# 268        Terrence Jones  0.000
# 325        Tahjere McCall  0.000
# 356    Donatas Motiejunas  0.000
# 360           Dzanan Musa  0.000
# 502         C.J. Williams  0.000
# 168        Melvin Frazier  0.250
# 310           Tyler Lydon  0.333
# 451          Ray Spalding  0.333
# 324      Luc Mbah a Moute  0.400
# 27             Lonzo Ball  0.417
# 283          Kosta Koufos  0.417
# 472        Gary Trent Jr.  0.429
# 499      Hassan Whiteside  0.449
# 56           Jonah Bolden  0.481
# 3            Steven Adams  0.500
# 16   Kostas Antetokounmpo  0.500
# 61           Tony Bradley  0.500
# 128         Angel Delgado  0.500
